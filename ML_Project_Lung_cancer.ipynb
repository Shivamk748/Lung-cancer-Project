# %% [markdown]
# # Project:-  Lung Cancer Prediction Based on Lifestyle and Medical Factors

# %% [markdown]
# **Project Objective:**
#
# Lung Cancer Prediction Based on Lifestyle and Medical Factors
# The objective of this project is to develop a machine learning model to predict the likelihood of lung cancer presence in patients based on a set of lifestyle and medical symptoms. This model aims to assist in early detection and improve diagnostic accuracy by evaluating a patient's risk level through specific indicators, making it a useful tool for healthcare providers.
#
# **Problem Statement:**
#
# Lung cancer remains one of the leading causes of cancer-related deaths worldwide. Early diagnosis is crucial for effective treatment and improving survival rates. This project uses machine learning to analyze patient data based on lifestyle habits and medical symptoms, predicting the presence of lung cancer. Each patient is assessed on several factors, including:
#
#
# #### 1. Gender
#
#  Type: Categorical (M/F)
#
# Description: Identifies the gender of the patient. Studies have shown that lung cancer risks can vary between males and females due to biological and lifestyle differences.
#
# #### 2. Age
# Type: Numerical
#
# Description: Represents the patient’s age. Age is a significant factor, as the risk of lung cancer generally increases with age.
#
# #### 3. Smoking
# Type: Binary (YES=2, NO=1)
#
# Description: Indicates whether the patient is a smoker. Smoking is the leading cause of lung cancer, making it one of the most critical risk factors in this analysis.
#
# #### 4. Yellow Fingers
# Type: Binary (YES=2, NO=1)
#
# Description: Signifies whether the patient has yellow-stained fingers, which is often associated with nicotine use. This can be an indicator of heavy or prolonged smoking.
#
# ####5. Anxiety
# Type: Binary (YES=2, NO=1)
#
# Description: Measures the presence of anxiety in the patient. Anxiety can be both a result of health issues and a contributing factor due to lifestyle choices, indirectly affecting health.
#
# ####6. Peer Pressure
# Type: Binary (YES=2, NO=1)
#
# Description: Indicates whether peer pressure influences the patient. Peer pressure can affect lifestyle choices, like smoking or drinking, which in turn impacts lung cancer risk.
#
# ####7. Chronic Disease
# Type: Binary (YES=2, NO=1)
#
# Description: Notes the presence of other chronic diseases. Patients with other chronic conditions may have compromised health, increasing susceptibility to lung cancer.
#
# ####8. Fatigue
# Type: Binary (YES=2, NO=1)
#
# Description: Indicates if the patient experiences fatigue. Persistent fatigue can be a symptom of lung cancer or other underlying health issues that may correlate with lung cancer risk.
#
# #####9. Allergy
# Type: Binary (YES=2, NO=1)
#
# Description: Indicates if the patient has allergies. While not a direct risk factor, allergy symptoms may overlap with lung cancer symptoms, impacting diagnosis.
#
# ####10. Wheezing
# Type: Binary (YES=2, NO=1)
#
# Description: Refers to the presence of wheezing or breathing difficulties. Wheezing is a respiratory symptom that may be linked to lung issues, including lung cancer.
#
# ####11. Alcohol Consumption
# Type: Binary (YES=2, NO=1)
# Description: Indicates if the patient consumes alcohol. Excessive alcohol use has been linked to a variety of cancers and can be a lifestyle indicator in risk assessment.
#
# #### 12. Coughing
# Type: Binary (YES=2, NO=1)
#
# Description: Notes if the patient has a persistent cough. Chronic coughing is a common symptom of lung cancer and thus a significant attribute.
#
# #### 13. Shortness of Breath
# Type: Binary (YES=2, NO=1)
# Description: Indicates whether the patient experiences shortness of breath. This can be a sign of respiratory issues related to lung cancer.
#
# #### 14. Swallowing Difficulty
# Type: Binary (YES=2, NO=1)
# Description: Marks any difficulty the patient has swallowing. Although not a direct symptom, it can indicate complications in respiratory or chest health.
#
# #### 15. Chest Pain
# Type: Binary (YES=2, NO=1)
# Description: Indicates if the patient has chest pain, which can be a severe symptom of lung cancer or other lung-related issues.
#
# #### 16. Lung Cancer
# Type: Target Variable (YES/NO)
#
# Description: The target variable indicates the presence (YES) or absence (NO) of lung cancer. The model aims to predict this attribute based on the above factors.
#
#
# Each of these attributes contributes uniquely to assessing the likelihood of lung cancer, either through direct association with symptoms or through lifestyle factors that influence overall health and lung cancer risk.
#
# By analyzing these attributes, the model seeks to predict lung cancer presence effectively, helping clinicians prioritize high-risk individuals for further testing and intervention.
#
#
# #### About Dataset
# The effectiveness of cancer prediction system helps the people to know their cancer risk with low cost and it also helps the people to take the appropriate decision based on their cancer risk status. The data is collected from the website online lung cancer prediction system .
#
# **Total no. of attributes**: 16
#
# **No .of instances**: 309
#
#
# ### In Brief, Project Aims to:
#
# ###Develop a Predictive Model:
#
# Create a machine learning model that accurately predicts the likelihood of lung cancer presence based on patient data.
#
# ### Identify Key Risk Factors:
#
# Analyze which lifestyle choices and medical symptoms most significantly contribute to lung cancer risk, aiding in early detection efforts.
#
# ### Enhance Early Diagnosis:
# Provide a tool that can assist healthcare professionals in identifying high-risk individuals for further screening and preventive care.
#
# ### Provide Insightful Data Analysis:
# Perform exploratory data analysis to visualize trends and correlations within the dataset, revealing impactful factors related to lung cancer.
#
# ### Optimize Model Performance:
#  Experiment with multiple classification algorithms and hyperparameter tuning to achieve high predictive accuracy, focusing on metrics like accuracy, precision, recall, and AUC-ROC.
#
# ### Build an Accessible Application :
# Implement a user-friendly interface (e.g., using Streamlit) to allow users to input patient data and receive a lung cancer risk prediction.

# %%
import pandas as pd         # importing important Library
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, KFold,StratifiedKFold,GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,accuracy_score,confusion_matrix,classification_report,recall_score,precision_score, f1_score,roc_curve,roc_auc_score,auc
import streamlit as st
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\shivam srivastava\Downloads\lung cancer data.csv")   # load data

# %%
df.head()   # display top 5 rows
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
df.shape   # size of data set
# Out:
# (309, 16)

# %%
df.isnull().sum()     # checking null values
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
df.dtypes            # dataTypes
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL CONSUMING         int64
# COUGHING                  int64
# SHORTNESS OF BREATH       int64
# SWALLOWING DIFFICULTY     int64
# CHEST PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
df.info()            # information about datatype and null vales for each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
df.describe()    # description about data
# Out:
#               AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  \
# count  309.000000  309.000000      309.000000  309.000000     309.000000
# mean    62.673139    1.563107        1.569579    1.498382       1.501618
# std      8.210301    0.496806        0.495938    0.500808       0.500808
# min     21.000000    1.000000        1.000000    1.000000       1.000000
# 25%     57.000000    1.000000        1.000000    1.000000       1.000000
# 50%     62.000000    2.000000        2.000000    1.000000       2.000000
# 75%     69.000000    2.000000        2.000000    2.000000       2.000000
# max     87.000000    2.000000        2.000000    2.000000       2.000000
#
#        CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  ALCOHOL CONSUMING  \
# count       309.000000  309.000000  309.000000  309.000000         309.000000
# mean          1.504854    1.673139    1.556634    1.556634           1.556634
# ...

# %% [markdown]
# # Step 1. Data Preprocessing:

# %%
categorical=df.select_dtypes(include='object').columns.to_list()    # categorical columns
categorical
# Out:
# ['GENDER', 'LUNG_CANCER']

# %%
numerical=df.select_dtypes(include=('int64','float64')).columns.to_list()   # numerical columns
numerical
# Out:
# ['AGE',
#  'SMOKING',
#  'YELLOW_FINGERS',
#  'ANXIETY',
#  'PEER_PRESSURE',
#  'CHRONIC DISEASE',
#  'FATIGUE ',
#  'ALLERGY ',
#  'WHEEZING',
#  'ALCOHOL CONSUMING',
#  'COUGHING',
#  'SHORTNESS OF BREATH',
#  'SWALLOWING DIFFICULTY',
#  'CHEST PAIN']

# %%
# Separate features and target
x = df.drop('LUNG_CANCER', axis=1)
y = df['LUNG_CANCER']

# %%
# Separate categorical and numerical features

categorical = x.select_dtypes(include='object').columns.to_list()

numerical = x.select_dtypes(include=('int64', 'float64')).columns.to_list()

# %%
# Split into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Scaling and Encoding

# %%
# Preprocessing: Scaling numerical data and encoding categorical data
scaler = StandardScaler()
encoder = OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)

# Fit and transform numerical data
x_train_scaled = scaler.fit_transform(x_train[numerical])
x_test_scaled = scaler.transform(x_test[numerical])

# Transform categorical data
x_train_encoded = encoder.fit_transform(x_train[categorical])
x_test_encoded = encoder.transform(x_test[categorical])

# %%
# Combine the scaled numerical features with encoded categorical features
x_train_final = np.hstack([x_train_scaled, x_train_encoded])
x_test_final = np.hstack([x_test_scaled, x_test_encoded])

# %%
# Train the model
model = LogisticRegression(random_state=42)
model.fit(x_train_final, y_train)
# Out:
# LogisticRegression(random_state=42)

# %% [markdown]
# # Step 2. Exploratory Data Analysis(EDA)

# %%
# histogram plot
plt.figure(figsize=(20,15))
pt=1

for column in df[numerical]:
    ax=plt.subplot(3,5,pt)
    sns.histplot(df[column],bins=20,ax=ax,kde=True,color='red',alpha=0.8)
    ax.set_xlabel(column)
    pt+=1
plt.tight_layout()
plt.show()

# %%
 #bar plot showing the count of each unique value in LUNG_CANCER.
plt.figure(figsize=(6,4))
sns.countplot(df['LUNG_CANCER'],color='g')
plt.title("Distribution of Lung Cancer")
plt.show()

# %%
plt.figure(figsize=(6,8))
sns.displot(df['AGE'],kde=True)
plt.title("Distribution of Age with KDE")
plt.show()

# %%
sns.barplot(y=df['AGE'],x=df['LUNG_CANCER'],palette=['r', 'g'])
plt.title(" Age by Lung Cancer Status")
plt.xlabel("Lung Cancer")
plt.ylabel(" Age")
plt.show()

# %%
# Plot the bar plot of average age by smoking status
sns.barplot(y=df['AGE'], x=df['SMOKING'],palette=['r', 'y'])

# Add title and labels
plt.title(" Age by Smoking Status")
plt.xlabel("Smoking Status")
plt.ylabel(" Age")
plt.legend(["1=No", "2=Yes"])
plt.show()

# %%
sns.barplot(x=df['LUNG_CANCER'],y=df['AGE'],hue=df['GENDER'],palette=['r', 'g'])
plt.title('Lung Cancer Age Distribution by Gender')
# Show the plot
plt.show()

# %%
plt.hist(data=df,x='AGE',bins=30)
plt.title('Histogram of Age distribution')
plt.xlabel('AGE')
plt.show()

# %%
plt.figure(figsize=(6,8))
nd=df['GENDER'].value_counts()
plt.pie(nd,labels=nd.index,autopct='%1.1f%%')
plt.title('Lung Cancer Percentage Based on Gender')
plt.legend(nd.index, title="Gender", loc="upper left")
plt.show()

# %% [markdown]
# ## Lung cancer is more dominant in males than in females but the difference is not very large

# %%
plt.figure(figsize=(12,6))
sns.barplot(df['AGE'].value_counts())
plt.title('Age Distribution')
plt.xlabel('AGE')
plt.ylabel('value counts')
# Out:
# Text(0, 0.5, 'value counts')

# %%
# distribution of data based on given feature
sns.pairplot(df[['AGE','SMOKING','COUGHING','SHORTNESS OF BREATH']])
plt.show()

# %%
sns.boxplot(x=df['AGE'])   # boxplot to show outliers in Age
# Out:
# <Axes: xlabel='AGE'>

# %%
# one outlier is present in AGE column

# %%
# checking outlier in all the columns
df_num=df.select_dtypes(include='number')
for i in df_num:
    q1=df_num[i].quantile(0.25)
    q3=df_num[i].quantile(0.75)
    iqr=q3-q1
    lower=q1-1.5*iqr
    upper=q3+1.5*iqr
    if df_num[df_num[i]>upper].any(axis=None):
       df_num.loc[df[i]>upper,i]=upper

    if df_num[df_num[i]<lower].any(axis=None):
        df_num.loc[df[i]<lower,i]=lower

    else:
        print(i,'No')
# Out:
# SMOKING No
# YELLOW_FINGERS No
# ANXIETY No
# PEER_PRESSURE No
# CHRONIC DISEASE No
# FATIGUE  No
# ALLERGY  No
# WHEEZING No
# ALCOHOL CONSUMING No
# COUGHING No
# SHORTNESS OF BREATH No
# SWALLOWING DIFFICULTY No
# CHEST PAIN No

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.select_dtypes(include=('int64','float64')).corr(method='pearson'),annot=True,cmap='plasma')
plt.title('correlation Heatmap of all features')
plt.show()

# %% [markdown]
# # Step 3. Model Selection:

# %%
# Train the model Logistic Regression
model1 = LogisticRegression(random_state=42)
model1.fit(x_train_final, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred_log=model1.predict(x_test_final)    # Model PREDICTION
accuracy_log=accuracy_score(y_test,y_pred_log)
accuracy_log
# Out:
# 0.978494623655914

# %% [markdown]
# #### Accuracy of Logistic Regression is  0.978494623655914

# %%
model2=DecisionTreeClassifier()   # training model DecisionTree
model2.fit(x_train_final,y_train)

y_pred_tree=model2.predict(x_test_final)

accuracy_tree=accuracy_score(y_test,y_pred_tree)
accuracy_tree
# Out:
# 0.9354838709677419

# %% [markdown]
# #### Accuracy of DecisionTreeClassifier is 0.9354838709677419

# %%
model3=RandomForestClassifier()    # training model Randomforest
model3.fit(x_train_final,y_train)

y_pred_random_forest=model2.predict(x_test_final)

accuracy_random_forest=accuracy_score(y_test,y_pred_random_forest)
accuracy_random_forest
# Out:
# 0.9354838709677419

# %% [markdown]
# #### Accuracy of Randomforest Classifier is 0.9354838709677419

# %%
from sklearn.svm import SVC
model4=SVC()
model4.fit(x_train_final,y_train)

y_pred_svc=model2.predict(x_test_final)

accuracy_svc=accuracy_score(y_test,y_pred_svc)
accuracy_svc
# Out:
# 0.9354838709677419

# %% [markdown]
# #### Accuracy of support Vector Machine is  0.9354838709677419

# %%
# Define the combined models
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Support Vector Classifier': SVC(probability=True)
}


# Train and evaluate each model
for name, model in models.items():
    model.fit(x_train_final, y_train)
    y_pred = model.predict(x_test_final)
    print(f"{name} Accuracy: {accuracy_score(y_test, y_pred)}")
# Out:
# Logistic Regression Accuracy: 0.978494623655914
# Decision Tree Accuracy: 0.9247311827956989
# Random Forest Accuracy: 0.978494623655914
# Support Vector Classifier Accuracy: 0.956989247311828

# %% [markdown]
# ## 3(b).  Hyper parameter tuning

# %%
# Define your parameter grids
param_grids = {
    "Logistic Regression": {'C': [0.1, 1, 5,20,50,100], 'solver': ['lbfgs', 'liblinear']},
    "Support Vector Classifier": {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf']},
    "Decision Tree": {'max_depth': [5, 10, 15], 'min_samples_split': [2, 5, 10]},
    "Random Forest": {'n_estimators': [50, 100], 'max_depth': [10, 15], 'min_samples_split': [2, 5]}

}

# Initialize an empty list for results
best_params_results = {}

# Loop through each model and perform Grid Search
for model_name, model_instance in models.items():
    param_grid = param_grids[model_name]

    grid_search = GridSearchCV(model_instance, param_grid, cv=10, scoring='accuracy',n_jobs=-1)
    grid_search.fit(x_train_final, y_train)

    best_params_results[model_name] = grid_search.best_params_
    print(f"Best Hyperparameters for {model_name}:", grid_search.best_params_)
# Out:
# Best Hyperparameters for Logistic Regression: {'C': 1, 'solver': 'lbfgs'}
# Best Hyperparameters for Decision Tree: {'max_depth': 10, 'min_samples_split': 2}
# Best Hyperparameters for Random Forest: {'max_depth': 15, 'min_samples_split': 5, 'n_estimators': 50}
# Best Hyperparameters for Support Vector Classifier: {'C': 1, 'kernel': 'linear'}

# %%
# Model Accuracy after hypertuning parameters are provided
models = {
    'Logistic Regression': LogisticRegression(C= 1, solver= 'lbfgs'),
    'Decision Tree': DecisionTreeClassifier(max_depth= 10, min_samples_split=2),
    'Random Forest': RandomForestClassifier(max_depth= 15, min_samples_split= 5, n_estimators= 50),
    'Support Vector Classifier': SVC(C= 1, kernel= 'linear')
}

# Train and evaluate each model
best_model = None
best_score = 0
best_model_name=''
for name, model in models.items():
    model.fit(x_train_final, y_train)
    y_pred = model.predict(x_test_final)
    accuracy=accuracy_score(y_test, y_pred)
    print(f"{name} Accuracy: {accuracy_score(y_test, y_pred)}")

     # Select best model based on RMSE
    if best_score < accuracy:
        best_score = accuracy
        best_model = model
        best_model_name=name

print(f"\n Best Selected Model based on accuracy: {best_model_name}")
# Out:
# Logistic Regression Accuracy: 0.978494623655914
# Decision Tree Accuracy: 0.9247311827956989
# Random Forest Accuracy: 0.967741935483871
# Support Vector Classifier Accuracy: 0.967741935483871
#
#  Best Selected Model based on accuracy: Logistic Regression

# %% [markdown]
# #### Result:-  After Hyperparameter tuning accuracy of each model is improved .  Best model among all of these is Logistic Regression whose accuracy has improved to  97.84 % accuracy and best among other model preformance .

# %% [markdown]
# # Step 4. Model Evaluation:

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

# Function to evaluate and display all metrics for each model
def evaluate_model(name, model, x_test_final, y_test):
    # Predict and evaluate
    y_pred = model.predict(x_test_final)
    #y_prob = model.predict_proba(x_test)[:, 1] if hasattr(model, "predict_proba") else None  # For ROC

    # Calculate metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, pos_label='YES')  # Adjust pos_label based on  target variable, 1 taken as encoded previously
    recall = recall_score(y_test, y_pred, pos_label='YES')
    f1 = f1_score(y_test, y_pred, pos_label='YES')

    # Display metrics
    print(f"{name} Evaluation Metrics:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}\n")

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(f"{name} - Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

# Train and evaluate each model
for name, model in models.items():
    model.fit(x_train_final, y_train)
    evaluate_model(name, model, x_test_final, y_test)
# Out:
# Logistic Regression Evaluation Metrics:
# Accuracy: 0.9785
# Precision: 0.9773
# Recall: 1.0000
# F1-Score: 0.9885
# Decision Tree Evaluation Metrics:
# Accuracy: 0.9247
# Precision: 0.9647
# Recall: 0.9535
# F1-Score: 0.9591
# Random Forest Evaluation Metrics:
# Accuracy: 0.9677
# Precision: 0.9770
# Recall: 0.9884
# F1-Score: 0.9827
# Support Vector Classifier Evaluation Metrics:
# Accuracy: 0.9677
# Precision: 0.9770
# Recall: 0.9884
# F1-Score: 0.9827

# %% [markdown]
# # Result:
# It can be seen from confusion matrix that for False Negative  for Logistic Regression case is zero that should be minimmum
# and we have achieved zero so best model is Logistic Regression and False Positive case is 2 which is also less.
# most values lies in True positive which is 56 and  thus model is preforming well in prediction .
#
# Also Precision and recall are both high, with perfect recall (100%), meaning no positive cases were missed.
# The high F1-score shows an excellent balance between precision and recall, making the model highly reliable for this classification task.
#
# summary:
# An accuracy of 0.9785, your model correctly predicted 97.85% of the total instances.
# Precision of  97.73% of the instances the model predicted as positive were actually positive
# A recall of 1.0000 indicates that the model correctly identified all actual positive instances (no false negatives)
# The F1-score of 0.9885 combines both precision and recall, giving a balanced view of the model’s performance, especially useful when you want to balance false positives and false negatives

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Function to evaluate and plot ROC Curve for each model
def evaluate_model(name, model, x_test_final, y_test):
    # Check if the model has a predict_proba method (not all models do)
    if hasattr(model, "predict_proba"):
        # Get the probabilities of the positive class (class 1)
        y_proba = model.predict_proba(x_test_final)[:, 1]

        # Compute ROC curve and AUC score
        fpr, tpr, _ = roc_curve(y_test, y_proba,pos_label='YES')
        roc_auc = auc(fpr, tpr)

        # Plot the ROC curve
        plt.figure()
        plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title(f"{name} - ROC Curve")
        plt.legend(loc="lower right")
        plt.show()
    else:
        print(f"{name} does not support probability predictions (predict_proba)")

# Train and evaluate each model
for name, model in models.items():
    model.fit(x_train_final, y_train)
    evaluate_model(name, model, x_test_final, y_test)
# Out:
# Support Vector Classifier does not support probability predictions (predict_proba)

# %% [markdown]
# ### Result

# %% [markdown]
# Higher AUC values (closer to 1) generally indicate better model performance.
# The Area Under the Curve (AUC) appears to be high (likely close to 1), suggesting
# the model has excellent discriminatory power between positive and negative classes.
#
# Logistic Regression and Random Forest have better ROC curves that suggest better performance compared to the Decision Tree.
# Random Forest generally performs better than a single Decision Tree because it reduces overfitting by combining multiple trees.
#
# The Random Forest and Logistic Regression models are both good choices based on these curves, but if Random Forest has
# a slightly higher AUC, it may be the better model for my  lung cancer prediction task as accuracy for Logistic Regression is more.

# %% [markdown]
# # Step 5. Deployment

# %%
# Save the model and preprocessing objects
joblib.dump(model, 'Lung_Cancer_Prediction.pkl')
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(encoder, 'encoders.pkl')

print("Model trained and saved successfully.")
# Out:
# Model trained and saved successfully.

# %%
# pip install streamlit

# %%
# %%writefile appnew.py

import joblib
import numpy as np
import streamlit as st
import pandas as pd

# Load the trained model and preprocessing objects
model = joblib.load('Lung_Cancer_Prediction.pkl')
scaler = joblib.load('scaler.pkl')
encoder = joblib.load('encoders.pkl')

# Streamlit app title and description
st.title("Lung Cancer Prediction")
st.write("Enter the patient's information below to predict the likelihood of lung cancer.")

# User inputs for the Streamlit app
gender = st.selectbox("Gender", ["M", "F"])
age = st.slider("Age", 18, 100)
smoking = st.selectbox("Smoking Habit", [1, 2], format_func=lambda x: "Yes" if x == 2 else "No")
yellow_fingers = st.selectbox("Yellow Fingers", [1, 2], format_func=lambda x: "Yes" if x == 2 else "No")
anxiety = st.selectbox("Anxiety", [1, 2], format_func=lambda x: "Yes" if x == 2 else "No")
peer_pressure = st.selectbox("Peer Pressure", [1, 2], format_func=lambda x: "Yes" if x == 2 else "No")
chronic_disease = st.selectbox("Chronic Disease", [1, 2], format_func=lambda x: "Yes" if x == 2 else "No")
fatigue = st.selectbox("Fatigue", [1, 2], format_func=lambda x: "Yes" if x == 2 else "No")
allergy = st.selectbox("Allergy", [1, 2], format_func=lambda x: "Yes" if x == 2 else "No")
wheezing = st.selectbox("Wheezing", [1, 2], format_func=lambda x: "Yes" if x == 2 else "No")
alcohol_consuming = st.selectbox("Alcohol Consuming", [1, 2], format_func=lambda x: "Yes" if x == 2 else "No")
coughing = st.selectbox("Coughing", [1, 2], format_func=lambda x: "Yes" if x == 2 else "No")
shortness_of_breath = st.selectbox("Shortness of Breath", [1, 2], format_func=lambda x: "Yes" if x == 2 else "No")
swallowing_difficulty = st.selectbox("Swallowing Difficulty", [1, 2], format_func=lambda x: "Yes" if x == 2 else "No")
chest_pain = st.selectbox("Chest Pain", [1, 2], format_func=lambda x: "Yes" if x == 2 else "No")

# Process inputs for prediction

# Encode the gender input using the pre-trained encoder
encoded_gender = encoder.transform(pd.DataFrame([gender], columns=["GENDER"]))

# Combine all features (encoded gender + other features)
inputs = np.array([
    *encoded_gender[0],  # Encoded gender
    age,
    smoking,
    yellow_fingers,
    anxiety,
    peer_pressure,
    chronic_disease,
    fatigue,
    allergy,
    wheezing,
    alcohol_consuming,
    coughing,
    shortness_of_breath,
    swallowing_difficulty,
    chest_pain
]).reshape(1, -1)

# Scale the numerical inputs (excluding the categorical gender)
inputs[:, 1:] = scaler.transform(inputs[:, 1:])

# Make prediction
if st.button("Predict Lung Cancer"):               # button to predict result
    prediction = model.predict(inputs)
    st.write("Lung cancer prediction :", prediction[0] )
# Out:
# Writing appnew.py

# %% [markdown]
#  # Run Streamlit in the background

# %%
# Run Streamlit in the background  for jupiter notebook
! streamlit run appnew.py & npx localtunnel --port 8501
# Out:
# ^C
